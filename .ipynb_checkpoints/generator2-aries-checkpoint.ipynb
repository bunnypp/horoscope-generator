# %% [markdown]
# # Horoscope Generator

# %% [markdown]
# Train a machine learning model and generate horoscopes based on dataset from horoscope.com

# %% [markdown]
# I followed this guide: https://www.kaggle.com/code/shivamb/beginners-guide-to-text-generation-using-lstms

# %% [markdown]
# First import modules:

# %%
import tensorflow as tf


tf.__version__
# Out:
# '2.10.0'

# %%
# keras module for building LSTM 
from keras_preprocessing.sequence import pad_sequences
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras import utils as ku

# set seeds for reproducability
from numpy.random import seed
tf.random.set_seed(2)
seed(1)

import pandas as pd
import numpy as np
import string, os 

import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Import the dataset:

# %%
import pandas as pd
import re

df = pd.read_json('dataset2/Aries.json')
corpus = list(df["text"])
print(corpus)
# Out:
# ['even though you might have to work today aries you should still try and take things fairly easy youre just not ready to embrace your workload with your usual vigor be sure to eat a healthy breakfast and lunch as your body may be rebelling from some recent indulgences soup and a salad are advisable for lunch along with plenty of water by days end you will feel your energy begin to return', 'this is a day when you could greatly benefit from spending some time outdoors in quiet reflection aries even a halfhours walk through a city park will help you feel more rested and grounded you have been working especially hard lately and need some time to refill the well of your soul dont deny yourself some downtime otherwise youre at risk of burning out', 'quite the contrary now is the time to put your original ideas to the test but this time you have the backing of the higherups dont be nervous just do what you had planned to do all along if you work hard youre likely to see tremendous profess
# ...

# %% [markdown]
# # Generate Sequences of N-gram Tokens

# %%
tokenizer = Tokenizer()

def get_sequence_of_tokens(corpus):
    ## tokenization
    tokenizer.fit_on_texts(corpus)
    total_words = len(tokenizer.word_index) + 1
    
    ## convert data to sequence of tokens 
    input_sequences = []
    for line in corpus:
        token_list = tokenizer.texts_to_sequences([line])[0]
        for i in range(1, len(token_list)):
            n_gram_sequence = token_list[:i+1]
            input_sequences.append(n_gram_sequence)
    return input_sequences, total_words

inp_sequences, total_words = get_sequence_of_tokens(corpus)
inp_sequences[:10]
# Out:
# [[76, 276],
#  [76, 276, 1],
#  [76, 276, 1, 22],
#  [76, 276, 1, 22, 21],
#  [76, 276, 1, 22, 21, 2],
#  [76, 276, 1, 22, 21, 2, 49],
#  [76, 276, 1, 22, 21, 2, 49, 14],
#  [76, 276, 1, 22, 21, 2, 49, 14, 9],
#  [76, 276, 1, 22, 21, 2, 49, 14, 9, 1],
#  [76, 276, 1, 22, 21, 2, 49, 14, 9, 1, 52]]

# %% [markdown]
# # Pad the sequences and obtain variables : Predictors and Target

# %%
def generate_padded_sequences(input_sequences):
    max_sequence_len = max([len(x) for x in input_sequences])
    input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))
    
    predictors, label = input_sequences[:,:-1],input_sequences[:,-1]
    label = ku.to_categorical(label, num_classes=total_words)
    return predictors, label, max_sequence_len

predictors, label, max_sequence_len = generate_padded_sequences(inp_sequences)

# %% [markdown]
# # Create and fit the model

# %%
def create_model(max_sequence_len, total_words):
    input_len = max_sequence_len - 1
    model = Sequential()
    
    # Add Input Embedding Layer
    model.add(Embedding(total_words, 10, input_length=input_len))
    
    # Add Hidden Layer 1 - LSTM Layer
    model.add(LSTM(100))
    model.add(Dropout(0.1))
    
    # Add Output Layer
    model.add(Dense(total_words, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam')
    
    return model

model = create_model(max_sequence_len, total_words)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 89, 10)            27140
#
#  lstm (LSTM)                 (None, 100)               44400
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 2714)              274114
#
# ...
# Total params: 345,654
# Trainable params: 345,654
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(predictors, label, epochs=100, verbose=5)
# Out:
# Epoch 1/100
# 2022-10-01 14:19:30.594055: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-01 14:19:31.064253: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-10-01 14:19:31.177243: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-10-01 14:19:31.445095: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# ...

# %%
model.save("model2-1.h5")
print("model saved")
# Out:
# model saved

# %%
results = model.evaluate(x=predictors, y=label)
results
# Out:
# 2022-10-01 14:53:36.829844: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-10-01 14:53:36.888795: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 567/567 [==============================] - 8s 14ms/step - loss: 0.8840
# 0.8840222954750061

# %% [markdown]
# # Generating the text

# %%
def generate_text(seed_text, next_words, model, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)
        
        output_word = ""
        for word,index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " "+output_word
    return seed_text.title()

# %%
print(generate_text("today", 100, model, max_sequence_len))
print('--')
print(generate_text("you", 100, model, max_sequence_len))
print('--')
print(generate_text("aries", 100, model, max_sequence_len))
# Out:
# Today Is A Terrific Day For You Aries You Aries You Might Find Upsetting Bear In This So Youre Important That Youll Probably Find Yourself Much More Of You Could Surprise You If Youre Surrounded Of Your Destiny To Your Situation Should Be Behind You Today Aries Busy And Bad On A While By Going On A Quick Day To Commit You Your Emotions And Ask Only To You Realize Of Electrical Fingertips Today Could Be A Critical Element To Healing But Your Partner Is The Most Or Sign And Lunch In The Matter You Can Work Out Of Warm And
# --
# ...
